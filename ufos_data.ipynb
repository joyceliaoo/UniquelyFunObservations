# %% [markdown]
# <a href="https://colab.research.google.com/github/joyceliaoo/papyroloreeeee/blob/master/ufos_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  

pd.options.display.max_columns
pd.options.display.max_rows
# Out:
# 60

# %%
# !git clone https://<usr-name>:<pw>@github.com/joyceliaoo/papyroloreeeee
        
# !ls
# Out:
# /bin/bash: usr-name: No such file or directory
# papyroloreeeee	sample_data  ufos_cleaned_1.csv

# %%
ufos_raw = pd.read_csv('papyroloreeeee/ufo_data/ufo_sighting_data.csv')

ufos_raw.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
# 5  10/10/1961 19:00               bristol             tn      us    sphere
# 6  10/10/1965 21:00    penarth (uk/wales)            NaN      gb    circle
# 7  10/10/1965 23:45               norwalk             ct      us      disk
# ...

# %%
ufos_1 = ufos_raw.drop(columns="description")
ufos_1 = ufos_1.drop(columns="date_documented")
ufos_1 = ufos_1.drop(columns="described_duration_of_encounter")

ufos_1.rename(columns={"Date_time": "date_time"}, inplace=True)
ufos_1.rename(columns={"length_of_encounter_seconds": "len_encounter_secs"}, inplace=True)

ufos_1.columns
# Out:
# Index(['date_time', 'city', 'state/province', 'country', 'UFO_shape',
#        'len_encounter_secs', 'latitude', 'longitude'],
#       dtype='object')

# %%
ufos_1.loc[ufos_1['country'] == 'us']
# Out:
#               date_time                                   city state/province  \
# 0      10/10/1949 20:30                             san marcos             tx
# 3      10/10/1956 21:00                                   edna             tx
# 4      10/10/1960 20:00                                kaneohe             hi
# 5      10/10/1961 19:00                                bristol             tn
# 7      10/10/1965 23:45                                norwalk             ct
# 8      10/10/1966 20:00                              pell city             al
# 9      10/10/1966 21:00                               live oak             fl
# 10     10/10/1968 13:00                              hawthorne             ca
# 11     10/10/1968 19:00                                brevard             nc
# 12     10/10/1970 16:00                               bellmore             ny
# 13     10/10/1970 19:00                             manchester             ky
# ...

# %%
ufos_1.loc[(ufos_1['city'].isin(['uk'])) & (ufos_1['country'].hasnans)]  = "gb"
ufos_1

ufos_1.loc[(ufos_1['city'].isin(['canada'])) & (ufos_1['country'].hasnans)]  = "ca"
ufos_1

#ufos_1.loc[(ufos_1['city'].isin(['canada'])) & (ufos_1['country'].hasnans)]  = "ca"
#ufos_1.loc[ufos_1['city'].isin(['canada'])]
# Out:
#               date_time                                   city state/province  \
# 0      10/10/1949 20:30                             san marcos             tx
# 1      10/10/1949 21:00                           lackland afb             tx
# 2      10/10/1955 17:00                   chester (uk/england)            NaN
# 3      10/10/1956 21:00                                   edna             tx
# 4      10/10/1960 20:00                                kaneohe             hi
# 5      10/10/1961 19:00                                bristol             tn
# 6      10/10/1965 21:00                     penarth (uk/wales)            NaN
# 7      10/10/1965 23:45                                norwalk             ct
# 8      10/10/1966 20:00                              pell city             al
# 9      10/10/1966 21:00                               live oak             fl
# 10     10/10/1968 13:00                              hawthorne             ca
# ...

# %%
ufos_1
# Out:
#               date_time                                   city state/province  \
# 0      10/10/1949 20:30                             san marcos             tx
# 1      10/10/1949 21:00                           lackland afb             tx
# 2      10/10/1955 17:00                   chester (uk/england)            NaN
# 3      10/10/1956 21:00                                   edna             tx
# 4      10/10/1960 20:00                                kaneohe             hi
# 5      10/10/1961 19:00                                bristol             tn
# 6      10/10/1965 21:00                     penarth (uk/wales)            NaN
# 7      10/10/1965 23:45                                norwalk             ct
# 8      10/10/1966 20:00                              pell city             al
# 9      10/10/1966 21:00                               live oak             fl
# 10     10/10/1968 13:00                              hawthorne             ca
# ...

# %%
ufos_1.to_csv("ufos_cleaned_1.csv", index=False, encoding='utf8')

from google.colab import files

files.download('ufos_cleaned_1.csv')
